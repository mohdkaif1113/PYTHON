# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sales = pd.read_csv(r"D:\Python Foundation Case Study 4 - Python Visualization Case Study\Case Study 4 - Python Visualizations Case Study\SalesData.csv")
sales.head()
# Out:
#    AccountId AccountName Region     Division       City State Tier Month  \
# 0       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Aug
# 1       1116    Account1   West  DIAMONDBACK  PHOENIX W    AZ  Low   Oct
# 2       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Jun
# 3       2391    Account2   East    MINUTEMEN   HARTFORD    CT  Med   Mar
# 4       2397    Account3   East    MINUTEMEN  WORCESTER    MA  Med   Sep
#
#    Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0       0.00   13208.52        0.0        4.0                0.70
# 1   10500.78   23114.91        3.0        7.0                0.84
# 2       0.00    6627.00        0.0        3.0                1.15
# 3   19881.00   13254.00        9.0        6.0                1.33
# 4    3684.48       0.00        1.0        0.0                1.02
#
#    TargetAchevied2016
# 0                1.53
# 1                1.31
# 2                1.29
# 3                1.17
# 4                1.53

# %% [markdown]
# #### 1. Compare Sales by region for 2016 with 2015 using bar chart

# %%
# sales1 = sales.groupby(['...']).aggregate(...) or .agg(..)
sales1 = sales.groupby(['Region'])[['Sales2015','Sales2016']].agg('sum')
sales1graph=sales1.plot.bar(figsize=(12,6))

# %% [markdown]
# #### 2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart..

# %%
sales.head(10)
# Out:
#    AccountId AccountName Region     Division         City State  Tier Month  \
# 0       1116    Account1   West  DIAMONDBACK    PHOENIX W    AZ   Low   Aug
# 1       1116    Account1   West  DIAMONDBACK    PHOENIX W    AZ   Low   Oct
# 2       2391    Account2   East    MINUTEMEN     HARTFORD    CT   Med   Jun
# 3       2391    Account2   East    MINUTEMEN     HARTFORD    CT   Med   Mar
# 4       2397    Account3   East    MINUTEMEN    WORCESTER    MA   Med   Sep
# 5       2400    Account4   East    MINUTEMEN     PORTLAND    ME  High   Jul
# 6       2400    Account4   East    MINUTEMEN     PORTLAND    ME  High   Feb
# 7       2404    Account5   East       EMPIRE   BRIDGEPORT    CT   Low   Mar
# 8       2406    Account6   East    BIG APPLE  JERSEY CITY    NJ   Med   Mar
# 9       2408    Account7   East    BIG APPLE  JERSEY CITY    NJ  High   Aug
#
#    Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0       0.00   13208.52        0.0        4.0                0.70
# 1   10500.78   23114.91        3.0        7.0                0.84
# 2       0.00    6627.00        0.0        3.0                1.15
# 3   19881.00   13254.00        9.0        6.0                1.33
# 4    3684.48       0.00        1.0        0.0                1.02
# 5       0.00   10525.24        0.0        4.0                1.03
# 6    2631.31   42812.62        1.0       17.0                1.08
# 7    4153.89    3918.77        1.0        1.0                0.79
# 8       0.00    6951.86        0.0        2.0                1.12
# 9       0.00   10994.54        0.0        4.0                1.11
#
#    TargetAchevied2016
# 0                1.53
# 1                1.31
# 2                1.29
# 3                1.17
# 4                1.53
# 5                1.45
# 6                0.99
# 7                1.46
# 8                1.02
# 9                1.54

# %%
sales2.Sales2016.plot.pie(figsize=(15,15))
# Out:
# <Axes: ylabel='Sales2016'>

# %% [markdown]
# #### 3. Compare the total sales of 2015 and 2016 with respect to Region and Tierss

# %%
#sales3 = sales.groupby([]).aggregate({})
sales3 = sales.groupby(['Region','Tier'])[['Sales2016','Sales2015']].sum()
sales3graph=sales3.plot.bar(figsize=(18,6))

# %% [markdown]
# #### 4. In East region, which state registered a decline in 2016 as compared to 2015??

# %%
#sales_east = sales[sales['Region']=='East'].sort_values('Sales2015', ascending=False).head(1)
sales_east_15_16 = sales[['Region','Sales2015','Sales2016']]
sales_east = sales_east_15_16[sales_east_15_16['Region']=='East'].sort_values('Sales2016').head(1)
sales_east
# Out:
#      Region  Sales2015  Sales2016
# 1641   East        0.0    -5846.4

# %% [markdown]
# #### 5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015??

# %%
a = [['10', '1.2', '4.2'], ['15', '70', '0.03'], ['8', '5', '0']]
df = pd.DataFrame(a, columns=['one', 'two', 'three'])
df['que'] = np.where((df['one'] >= df['two']) & (df['one'] <=df['three']), df['one'], np.nan)
df
# Out:
#   one  two three  que
# 0  10  1.2   4.2   10
# 1  15   70  0.03  NaN
# 2   8    5     0  NaN

# %%
sales_tier = sales[sales['Tier']=='High']
sales_division= sales_tier[['Division','Sales2015','Sales2016']]
sales_division['Decline'] = np.where((sales_division['Sales2015'] <=
sales_division['Sales2016']), True, False)
sales_division[sales_division['Decline'] == True].head()
# Out:
#      Division  Sales2015  Sales2016  Decline
# 5   MINUTEMEN       0.00   10525.24     True
# 6   MINUTEMEN    2631.31   42812.62     True
# 9   BIG APPLE       0.00   10994.54     True
# 10  BIG APPLE    9640.17   27316.66     True
# 17  BIG APPLE       0.00    3128.34     True

# %% [markdown]
# #### 6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. The Quarters are based on months and defined as - -

# %% [markdown]
# • Jan - Mar : Q1
# • Apr - Jun : Q2
# • Jul - Sep : Q3
# • Oct - Dec : Q4

# %%
sales.Month.unique()
# Out:
# array(['Aug', 'Oct', 'Jun', 'Mar', 'Sep', 'Jul', 'Feb', 'Apr', 'Nov',
#        'May', 'Dec', 'Jan'], dtype=object)

# %%
sales_qtr = sales[['Month','Sales2015','Sales2016']]
#sales_qtr['Qtr'] = pd.to_datetime(sales_qtr.Month).dt.quarter
#q = 'Q' + pd.to_datetime(df['Month'], format='%b').dt.quarter.rename('Qtr').astype(str)
#df = df.groupby(q).sum().reset_index()
# d = {'Jan':'Q1', 'Feb':'Q1', 'Mar':'Q1', 'Apr':'Q2', 'May':'Q2','Jun':'Q2', 'Jul':'Q3', 'Aug':'Q3',
# 'Sep':'Q3','Oct':'Q4', 'Nov':'Q4', 'Dec':'Q4'}
# sales_qtr.Month = sales_qtr.Month.map(d)
# sales_qtr.Month = np.where(sales_qtr.Month == 'Jan', 'Q1',
# np.where(sales_qtr.Month == 'Apr', 'Q2',
# np.where(sales_qtr.Month == 'Jul', 'Q3', None)))
sales_qtr.Month = np.where(sales_qtr.Month.isin(['Jan','Feb','Mar']), 'Q1',np.where(sales_qtr.Month.isin(['Apr','May','Jun']),'Q2',np.where(sales_qtr.Month.isin(['Jul','Aug','Sep']), 'Q3',np.where(sales_qtr.Month.isin(['Oct','Nov','Dec']), 'Q4',None))))
sales_qtr.head()
# Out:
#   Month  Sales2015  Sales2016
# 0    Q3       0.00   13208.52
# 1    Q4   10500.78   23114.91
# 2    Q2       0.00    6627.00
# 3    Q1   19881.00   13254.00
# 4    Q3    3684.48       0.00

# %% [markdown]
# #### 7. Compare Qtr wise sales in 2015 and 2016 in a bar plot

# %%
sa=sales_qtr.head(10)
#sa[['Month','Sales2015','Sales2016']].plot(kind='bar')
sales_qtr.groupby('Month').sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# #### 8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart..

# %%
list_sales = ['Sales2015','Sales2016']
#list_sales = df.columns.difference(['Month']).tolist()
agg_df = sales_qtr.groupby('Month').sum()
fig,axs = plt.subplots(1,len(list_sales),figsize=(10,10))
for i,ax in enumerate(axs):
 agg_df.plot.pie(y=list_sales[i],ax=ax)
 
sales_qtr.groupby('Month').sum().plot.pie(y=list_sales,subplots=((1,len(list_sales))),figsize=(10,10))
sales_qtr_month = sales_qtr.groupby(['Month']).agg('sum')
sales_qtr_month
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       5 for i,ax in enumerate(axs):
#       6  agg_df.plot.pie(y=list_sales[i],ax=ax)
# ----> 8 sales_qtr.groupby('Month').sum().plot.pie(y=list_sales,subplots=((1,len(list_sales))),figsize=(10,10))
#       9 sales_qtr_month = sales_qtr.groupby(['Month']).agg('sum')
#      10 sales_qtr_month
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1661, in PlotAccessor.pie(self, **kwargs)
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
#    1660     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1661 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:990, in PlotAccessor.__call__(self, *args, **kwargs)
#     988             # converted to series actually. copy to not modify
#     989             data = data[y].copy()
# --> 990             data.index.name = y
#     991 elif isinstance(data, ABCDataFrame):
#     992     data_cols = data.columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1680, in Index.name(self, value)
#    1674 if self._no_setting_name:
#    1675     # Used in MultiIndex.levels to avoid silently ignoring name updates.
#    1676     raise RuntimeError(
#    1677         "Cannot set name on a level of a MultiIndex. Use "
#    1678         "'MultiIndex.set_names' instead."
#    1679     )
# -> 1680 maybe_extract_name(value, None, type(self))
#    1681 self._name = value
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7627, in maybe_extract_name(name, obj, cls)
#    7625 # GH#29069
#    7626 if not is_hashable(name):
# -> 7627     raise TypeError(f"{cls.__name__}.name must be a hashable type")
#    7629 return name
#
# TypeError: Index.name must be a hashable type

# %%
sales_qtr_month = sales_qtr.groupby(['Month']).agg('sum')
sales_qtr_month
# Out:
#           Sales2015     Sales2016
# Month
# Q1     5.485800e+06  6.997953e+06
# Q2     5.390862e+06  7.237361e+06
# Q3     6.164094e+06  7.861546e+06
# Q4     5.713634e+06  7.567868e+06

# %%
sales_qtr_month.plot.pie(figsize=(10,10),subplots=True)
# Out:
# array([<Axes: ylabel='Sales2015'>, <Axes: ylabel='Sales2016'>],
#       dtype=object)

# %%
# Covert percent and total to value
def func(pct, allvals):
 absolute = int(round(pct/100*np.sum(allvals)))
 return "{:.1f}".format(absolute)
df_flatten = sales_qtr_month.copy()
df_flatten[col].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       4  return "{:.1f}".format(absolute)
#       5 df_flatten = sales_qtr_month.copy()
# ----> 6 df_flatten[col].tolist()
#
# NameError: name 'col' is not defined

# %%
f, axes = plt.subplots(1,2, figsize=(10,10))
for ax, col in zip(axes, df_flatten.columns):
 print(ax,col)
 df_flatten[col].plot(kind='pie', autopct=lambda pct: func(pct, df_flatten[col].tolist()), 
 labels=df_flatten.index, ax=ax, title=col, fontsize=10)
 ax.legend(loc=3)
# Out:
# Axes(0.125,0.11;0.352273x0.77) Sales2015
# Axes(0.547727,0.11;0.352273x0.77) Sales2016

# %% [markdown]
# ### Test Pie Chart example

# %%
labels = 'Iphone', 'Samsung', 'Motorola'
sizes = np.array([5860, 677, 3200])
colors = ['green', 'gold', 'blue']
p, tx, autotexts = plt.pie(sizes, labels=labels, colors=colors,autopct="", shadow=True)
for i, a in enumerate(autotexts):
 a.set_text("{}".format(sizes[i]))
plt.axis('equal')
plt.show()
